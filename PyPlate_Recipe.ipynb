# %% [markdown]
# # Merck Coding Challenge Part 1
#
# **Created by Jonathan Olson on May 13, 2024**
#
# Contact: jonnycoder@gmail.*com*

# %% [markdown]
# ## Requirements
# PyPlate requires Python 3.10 or greater.
#
#  Let's first ensure that requirement is satisfied.

# %%
# !python --version
import sys
if not sys.version_info >= (3, 10):
   print("Python version is less than 3.10")
# Out:
# Python 3.10.12

# %%
# !pip install pyplate-hte
# !pip3 install jinja2==3.0.1
# Out:
# Collecting pyplate-hte
#   Downloading pyplate_hte-0.4.6-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 806.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyplate-hte) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pyplate-hte) (2.0.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pyplate-hte) (6.0.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pyplate-hte) (0.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyplate-hte) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyplate-hte) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyplate-hte) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pyplate-hte) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pyplate-hte) (1.16.0)
# Installing collected packages: pyplate-hte
# Successfully installed pyplate-hte-0.4.6
# Collecting jinja2==3.0.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2==3.0.1) (2.1.5)
# Installing collected packages: jinja2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.0+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.0+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# Successfully installed jinja2-3.0.1

# %% [markdown]
# # Setup Experiment

# %%
import numpy as np
from pyplate import Substance, Container, Plate, Recipe

# Total runs
total_runs = 12

# Substances
pd2_catalyst = Substance.solid(name="Pd(OAc)2", mol_weight=224.51)
solvent_toluene = Substance.liquid(name="toluene", mol_weight=92.14, density=0.867)
solvent_glyme = Substance.liquid(name="glyme", mol_weight=90.12, density=0.869)
solvent_tbme = Substance.liquid(name="TBME", mol_weight=88.15, density=0.740)
solvent_dichloroethane = Substance.liquid(name="dichloroethane", mol_weight=98.96, density=1.256)
ligand_xphos = Substance.solid(name="XPhos", mol_weight=476.7)
ligand_sphos = Substance.solid(name="SPhos", mol_weight=410.53)
ligand_dppf = Substance.solid(name="dppf", mol_weight=554.38)

# Generate 12 molecular weight combinations of small molecules. Use a seed for repeatable results
np.random.seed(57)
A_mol_weights_list = np.random.uniform(100, 500, total_runs)
B_mol_weights_list = np.random.uniform(100, 500, total_runs)

# Create Ai & Bi: assume unique pairs of Ai and Bi to form 12 total reactions, not all possible pairings of Ai and Bi
A_solids = [Substance.solid(name=f"A{i}", mol_weight=mw) for i, mw in enumerate(A_mol_weights_list)]
B_solids = [Substance.solid(name=f"B{i}", mol_weight=mw) for i, mw in enumerate(B_mol_weights_list)]

# Lists
solvents = [solvent_toluene, solvent_glyme, solvent_tbme, solvent_dichloroethane]
ligands = [ligand_xphos, ligand_sphos, ligand_dppf]

# Total Experiments to guide in quantity of solutions
total_experiments = total_runs * len(solvents) * len(ligands)  # 144

# 96-well
plate_row_count = 8
plate_col_count = 12
well_count = plate_row_count * plate_col_count

temperatures = [60, 80]

# Assumption: different well plate for each temperature; a plate can only accommodate one temperature for all wells
plates60C = [Plate(name="60C - 96 Wells - A", max_volume_per_well="500 uL", rows=plate_row_count, columns=plate_col_count),
             Plate(name="60C - 96 Wells - B", max_volume_per_well="500 uL", rows=plate_row_count, columns=plate_col_count),
]
plates80C = [Plate(name="80C - 96 Wells - A", max_volume_per_well="500 uL", rows=plate_row_count, columns=plate_col_count),
             Plate(name="80C - 96 Wells - B", max_volume_per_well="500 uL", rows=plate_row_count, columns=plate_col_count)
]


# Constants
B_to_A_factor = 1.1
percent_pd = 10
percent_ligand = 15

# Ratios
mmol_A_reagent = 0.1
mmol_B_reagent = mmol_A_reagent * B_to_A_factor
mmol_pd = mmol_A_reagent * (percent_pd / 100)  # Assumption: Calculate from `A` limiting reagent only
mmol_ligand = mmol_A_reagent * (percent_ligand / 100)  # Assumption: Calculate from `A` limiting reagent only

# Concentrations - PyPlate supports ratios which will look like "0.1mmol/200uL"
reaction_volume = 200  # 200uL reaction volume
reaction_measure = "uL"
concentration_A = f"{mmol_A_reagent} mmol/{reaction_volume} {reaction_measure}"
concentration_B = f"{mmol_B_reagent} mmol/{reaction_volume} {reaction_measure}"
concentration_pd = f"{mmol_pd} mmol/{reaction_volume} {reaction_measure}"
concentration_ligand = f"{mmol_ligand} mmol/{reaction_volume} {reaction_measure}"

total_quantity = total_experiments * reaction_volume


def get_row_col(index):
    """
    Return row and column values for an 8x12 matrix, representing a standard 8x12 well plate.
    For example, index 1 is (0,0), index 1 is (0,1), etc

    Args:
        index: 1-based counter ranging from 1 to 144

    Returns: Converted row and column tuple.
    """
    zero_index = index - 1
    row = zero_index // 12
    col = zero_index % 12
    return row, col


recipe = Recipe()

# Add plates to recipe
for p in plates60C:
    recipe.uses(p)
for p in plates80C:
    recipe.uses(p)

index = 1  # tracks which well we are on for given 60C plate and 80C plate
current_plate_index = 0  # 144 reactions for given temp using 2 96-well plates

# For given temperature, we have 4 solvents * 3 ligands * 12 AiBi solids = 144 total reactions.
# We will mix each reaction one at a time, and transfer it to both 60C plate and 80C plate
# There are 2 60C plates and 2 80C plates to fill in total
for i, solvent in enumerate(solvents):
    for j, ligand in enumerate(ligands):
        for k, (a, b) in enumerate(zip(A_solids, B_solids)):
            # Start at row 1 column 1 and move to row 1 column 2 until plate is full
            row, col = get_row_col(index)

            # Each well is a unique mix of AiBi, Ligand, Solvent and pd2 catalyst
            mix = Container.create_solution(name=f"{a.name}, {b.name}, {ligand.name}, {pd2_catalyst.name} in {solvent.name}",
                                            solute=[a, b, ligand, pd2_catalyst],
                                            concentration=[concentration_A, concentration_B, concentration_ligand, concentration_pd],
                                            solvent=solvent,
                                            total_quantity=f"{total_quantity} {reaction_measure}")
            recipe.uses(mix)
            current_plate60C = plates60C[current_plate_index]
            current_plate80C = plates80C[current_plate_index]
            recipe.transfer(source=mix,
                            destination=current_plate60C[row+1, col+1],
                            quantity=f"{reaction_volume} {reaction_measure}")
            recipe.transfer(source=mix,
                            destination=current_plate80C[row + 1, col + 1],
                            quantity=f"{reaction_volume} {reaction_measure}")
            index += 1

            # Logic to move to next plate after filling all 96 wells
            if (index-1) % well_count == 0:
                current_plate_index += 1
                index = 1

# %% [markdown]
# # Bake Recipe and Analyze Results

# %%
results = recipe.bake()
print(results[plates60C[0].name].wells)
print(results[plates60C[1].name].wells)
print(results[plates80C[0].name].wells)
print(results[plates80C[1].name].wells)
# Out:
# [[+----------------+----------+----------+------------+-----+
#   |    well A,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 148.0 uL | 128.0 mg | 1.389 mmol |  -  |
#   |     Total      | 200.0 uL | 180.4 mg | 1.624 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 135.0 uL | 116.8 mg | 1.268 mmol |  -  |
#   |     Total      | 200.0 uL | 182.1 mg | 1.503 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 144.0 uL | 124.6 mg | 1.353 mmol |  -  |
#   |     Total      | 200.0 uL | 180.9 mg | 1.588 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 137.0 uL | 119.2 mg | 1.294 mmol |  -  |
#   |     Total      | 200.0 uL | 181.7 mg | 1.529 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 126.0 uL | 109.6 mg | 1.189 mmol |  -  |
#   |     Total      | 200.0 uL | 183.2 mg | 1.424 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 143.0 uL | 124.3 mg | 1.349 mmol |  -  |
#   |     Total      | 200.0 uL | 180.9 mg | 1.584 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 97.0 uL  | 83.7 mg  | 908.2 umol |  -  |
#   |     Total      | 200.0 uL | 187.2 mg | 1.143 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 126.0 uL | 109.1 mg | 1.184 mmol |  -  |
#   |     Total      | 200.0 uL | 183.3 mg | 1.419 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well A,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 110.0 uL | 95.6 mg  | 1.037 mmol |  -  |
#   |     Total      | 200.0 uL | 185.3 mg | 1.272 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well A,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 150.0 uL | 130.3 mg | 1.414 mmol |  -  |
#   |     Total      | 200.0 uL | 180.0 mg | 1.649 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well A,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 123.0 uL | 106.7 mg | 1.158 mmol |  -  |
#   |     Total      | 200.0 uL | 183.6 mg | 1.393 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well A,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 129.0 uL | 111.9 mg | 1.214 mmol |  -  |
#   |     Total      | 200.0 uL | 182.8 mg | 1.449 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+----------+----------+------------+-----+
#   |    well B,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 149.0 uL | 128.8 mg | 1.398 mmol |  -  |
#   |     Total      | 200.0 uL | 180.2 mg | 1.633 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 136.0 uL | 117.7 mg | 1.277 mmol |  -  |
#   |     Total      | 200.0 uL | 181.9 mg | 1.512 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 145.0 uL | 125.5 mg | 1.362 mmol |  -  |
#   |     Total      | 200.0 uL | 180.8 mg | 1.597 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 138.0 uL | 120.1 mg | 1.303 mmol |  -  |
#   |     Total      | 200.0 uL | 181.6 mg | 1.538 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 127.0 uL | 110.4 mg | 1.199 mmol |  -  |
#   |     Total      | 200.0 uL | 183.1 mg | 1.434 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 144.0 uL | 125.2 mg | 1.358 mmol |  -  |
#   |     Total      | 200.0 uL | 180.8 mg | 1.593 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 98.0 uL  | 84.5 mg  | 917.6 umol |  -  |
#   |     Total      | 200.0 uL | 187.0 mg | 1.153 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 127.0 uL | 109.9 mg | 1.193 mmol |  -  |
#   |     Total      | 200.0 uL | 183.1 mg | 1.428 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well B,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 111.0 uL | 96.4 mg  | 1.047 mmol |  -  |
#   |     Total      | 200.0 uL | 185.2 mg | 1.282 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well B,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 151.0 uL | 131.2 mg | 1.424 mmol |  -  |
#   |     Total      | 200.0 uL | 179.9 mg | 1.659 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well B,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 124.0 uL | 107.6 mg | 1.167 mmol |  -  |
#   |     Total      | 200.0 uL | 183.5 mg | 1.402 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well B,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 130.0 uL | 112.7 mg | 1.224 mmol |  -  |
#   |     Total      | 200.0 uL | 182.7 mg | 1.459 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+----------+----------+------------+-----+
#   |    well C,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 146.0 uL | 127.0 mg | 1.378 mmol |  -  |
#   |     Total      | 200.0 uL | 180.5 mg | 1.613 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 134.0 uL | 115.8 mg | 1.257 mmol |  -  |
#   |     Total      | 200.0 uL | 182.2 mg | 1.492 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 143.0 uL | 123.6 mg | 1.342 mmol |  -  |
#   |     Total      | 200.0 uL | 181.0 mg | 1.577 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 136.0 uL | 118.2 mg | 1.283 mmol |  -  |
#   |     Total      | 200.0 uL | 181.9 mg | 1.518 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 125.0 uL | 108.6 mg | 1.178 mmol |  -  |
#   |     Total      | 200.0 uL | 183.3 mg | 1.413 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 142.0 uL | 123.3 mg | 1.338 mmol |  -  |
#   |     Total      | 200.0 uL | 181.1 mg | 1.573 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 95.0 uL  | 82.7 mg  | 897.2 umol |  -  |
#   |     Total      | 200.0 uL | 187.3 mg | 1.132 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 125.0 uL | 108.1 mg | 1.173 mmol |  -  |
#   |     Total      | 200.0 uL | 183.4 mg | 1.408 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well C,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 109.0 uL | 94.6 mg  | 1.026 mmol |  -  |
#   |     Total      | 200.0 uL | 185.5 mg | 1.261 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well C,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 149.0 uL | 129.3 mg | 1.404 mmol |  -  |
#   |     Total      | 200.0 uL | 180.2 mg | 1.639 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well C,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 122.0 uL | 105.7 mg | 1.147 mmol |  -  |
#   |     Total      | 200.0 uL | 183.8 mg | 1.382 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well C,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |    toluene     | 128.0 uL | 110.9 mg | 1.203 mmol |  -  |
#   |     Total      | 200.0 uL | 183.0 mg | 1.438 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+----------+----------+------------+-----+
#   |    well D,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 148.0 uL | 128.3 mg | 1.423 mmol |  -  |
#   |     Total      | 200.0 uL | 180.7 mg | 1.658 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 135.0 uL | 117.1 mg |  1.3 mmol  |  -  |
#   |     Total      | 200.0 uL | 182.3 mg | 1.535 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 144.0 uL | 124.9 mg | 1.386 mmol |  -  |
#   |     Total      | 200.0 uL | 181.2 mg | 1.621 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 137.0 uL | 119.5 mg | 1.326 mmol |  -  |
#   |     Total      | 200.0 uL | 182.0 mg | 1.561 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 126.0 uL | 109.8 mg | 1.219 mmol |  -  |
#   |     Total      | 200.0 uL | 183.4 mg | 1.454 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 143.0 uL | 124.6 mg | 1.383 mmol |  -  |
#   |     Total      | 200.0 uL | 181.2 mg | 1.618 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 97.0 uL  | 83.9 mg  | 930.7 umol |  -  |
#   |     Total      | 200.0 uL | 187.4 mg | 1.166 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 126.0 uL | 109.3 mg | 1.213 mmol |  -  |
#   |     Total      | 200.0 uL | 183.5 mg | 1.448 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well D,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 110.0 uL | 95.8 mg  | 1.063 mmol |  -  |
#   |     Total      | 200.0 uL | 185.6 mg | 1.298 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well D,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 150.0 uL | 130.6 mg | 1.45 mmol  |  -  |
#   |     Total      | 200.0 uL | 180.3 mg | 1.685 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well D,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 123.0 uL | 106.9 mg | 1.187 mmol |  -  |
#   |     Total      | 200.0 uL | 183.9 mg | 1.422 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well D,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |     XPhos      |  7.0 uL  |  7.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 129.0 uL | 112.1 mg | 1.244 mmol |  -  |
#   |     Total      | 200.0 uL | 183.1 mg | 1.479 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+----------+----------+------------+-----+
#   |    well E,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 149.0 uL | 129.1 mg | 1.433 mmol |  -  |
#   |     Total      | 200.0 uL | 180.5 mg | 1.668 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 136.0 uL | 118.0 mg | 1.309 mmol |  -  |
#   |     Total      | 200.0 uL | 182.2 mg | 1.544 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 145.0 uL | 125.8 mg | 1.396 mmol |  -  |
#   |     Total      | 200.0 uL | 181.0 mg | 1.631 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 138.0 uL | 120.3 mg | 1.335 mmol |  -  |
#   |     Total      | 200.0 uL | 181.9 mg | 1.57 mmol  | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 127.0 uL | 110.7 mg | 1.228 mmol |  -  |
#   |     Total      | 200.0 uL | 183.3 mg | 1.463 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 144.0 uL | 125.5 mg | 1.392 mmol |  -  |
#   |     Total      | 200.0 uL | 181.1 mg | 1.627 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 98.0 uL  | 84.7 mg  | 940.3 umol |  -  |
#   |     Total      | 200.0 uL | 187.2 mg | 1.175 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 127.0 uL | 110.2 mg | 1.223 mmol |  -  |
#   |     Total      | 200.0 uL | 183.4 mg | 1.458 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well E,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 111.0 uL | 96.7 mg  | 1.073 mmol |  -  |
#   |     Total      | 200.0 uL | 185.4 mg | 1.308 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well E,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 151.0 uL | 131.5 mg | 1.459 mmol |  -  |
#   |     Total      | 200.0 uL | 180.2 mg | 1.694 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well E,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 124.0 uL | 107.8 mg | 1.196 mmol |  -  |
#   |     Total      | 200.0 uL | 183.7 mg | 1.431 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well E,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |     SPhos      |  6.0 uL  |  6.2 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 130.0 uL | 113.0 mg | 1.254 mmol |  -  |
#   |     Total      | 200.0 uL | 183.0 mg | 1.489 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+----------+----------+------------+-----+
#   |    well F,1    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A0       | 13.0 uL  | 13.5 mg  | 100.0 umol |  -  |
#   |       B0       | 30.0 uL  | 29.5 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 146.0 uL | 127.3 mg | 1.412 mmol |  -  |
#   |     Total      | 200.0 uL | 180.8 mg | 1.647 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,2    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A1       | 19.0 uL  | 19.2 mg  | 100.0 umol |  -  |
#   |       B1       | 37.0 uL  | 36.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 134.0 uL | 116.1 mg | 1.288 mmol |  -  |
#   |     Total      | 200.0 uL | 182.5 mg | 1.523 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,3    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A2       | 26.0 uL  | 26.4 mg  | 100.0 umol |  -  |
#   |       B2       | 20.0 uL  | 20.4 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 143.0 uL | 123.9 mg | 1.375 mmol |  -  |
#   |     Total      | 200.0 uL | 181.3 mg | 1.61 mmol  | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,4    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A3       | 22.0 uL  | 22.4 mg  | 100.0 umol |  -  |
#   |       B3       | 31.0 uL  | 30.7 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 136.0 uL | 118.5 mg | 1.314 mmol |  -  |
#   |     Total      | 200.0 uL | 182.1 mg | 1.549 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,5    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A4       | 33.0 uL  | 32.6 mg  | 100.0 umol |  -  |
#   |       B4       | 32.0 uL  | 31.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 125.0 uL | 108.8 mg | 1.207 mmol |  -  |
#   |     Total      | 200.0 uL | 183.6 mg | 1.442 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,6    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A5       | 32.0 uL  | 31.8 mg  | 100.0 umol |  -  |
#   |       B5       | 15.0 uL  | 15.4 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 142.0 uL | 123.6 mg | 1.371 mmol |  -  |
#   |     Total      | 200.0 uL | 181.4 mg | 1.606 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,7    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A6       | 42.0 uL  | 42.3 mg  | 100.0 umol |  -  |
#   |       B6       | 52.0 uL  | 51.8 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 95.0 uL  | 82.9 mg  | 919.5 umol |  -  |
#   |     Total      | 200.0 uL | 187.5 mg | 1.154 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,8    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A7       | 47.0 uL  | 46.7 mg  | 100.0 umol |  -  |
#   |       B7       | 18.0 uL  | 18.1 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 125.0 uL | 108.3 mg | 1.202 mmol |  -  |
#   |     Total      | 200.0 uL | 183.7 mg | 1.437 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |    well F,9    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A8       | 31.0 uL  | 30.9 mg  | 100.0 umol |  -  |
#   |       B8       | 49.0 uL  | 49.5 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 109.0 uL | 94.8 mg  | 1.052 mmol |  -  |
#   |     Total      | 200.0 uL | 185.7 mg | 1.287 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well F,10    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |       A9       | 27.0 uL  | 27.0 mg  | 100.0 umol |  -  |
#   |       B9       | 13.0 uL  | 13.3 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   |     glyme      | 149.0 uL | 129.6 mg | 1.438 mmol |  -  |
#   |     Total      | 200.0 uL | 180.5 mg | 1.673 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well F,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
# ...
#   |   well D,11    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A10       | 13.0 uL  | 12.9 mg  | 100.0 umol |  -  |
#   |      B10       | 55.0 uL  | 54.7 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   | dichloroethane | 122.0 uL | 153.1 mg | 1.547 mmol |  -  |
#   |     Total      | 200.0 uL | 231.2 mg | 1.782 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+
#   +----------------+----------+----------+------------+-----+
#   |   well D,12    |  Volume  |   Mass   |   Moles    |  U  |
#   +----------------+----------+----------+------------+-----+
#   | Maximum Volume |  500.0   |    -     |     -      |  -  |
#   |      A11       | 46.0 uL  | 45.9 mg  | 100.0 umol |  -  |
#   |      B11       | 16.0 uL  | 15.6 mg  | 110.0 umol |  -  |
#   |      dppf      |  8.0 uL  |  8.3 mg  | 15.0 umol  |  -  |
#   |    Pd(OAc)2    |  2.0 uL  |  2.2 mg  | 10.0 umol  |  -  |
#   | dichloroethane | 128.0 uL | 160.6 mg | 1.623 mmol |  -  |
#   |     Total      | 200.0 uL | 232.7 mg | 1.858 mmol | 0 U |
#   +----------------+----------+----------+------------+-----+]
#  [+----------------+--------+------+-------+-----+
#   |    well E,1    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,2    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,3    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,4    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,5    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,6    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,7    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,8    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well E,9    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well E,10    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well E,11    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well E,12    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+]
#  [+----------------+--------+------+-------+-----+
#   |    well F,1    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,2    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,3    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,4    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,5    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,6    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,7    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,8    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well F,9    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well F,10    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well F,11    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well F,12    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+]
#  [+----------------+--------+------+-------+-----+
#   |    well G,1    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,2    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,3    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,4    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,5    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,6    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,7    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,8    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well G,9    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well G,10    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well G,11    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well G,12    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+]
#  [+----------------+--------+------+-------+-----+
#   |    well H,1    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,2    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,3    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,4    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,5    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,6    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,7    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,8    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |    well H,9    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well H,10    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well H,11    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+
#   +----------------+--------+------+-------+-----+
#   |   well H,12    | Volume | Mass | Moles |  U  |
#   +----------------+--------+------+-------+-----+
#   | Maximum Volume | 500.0  |  -   |   -   |  -  |
#   |     Total      |  0 L   | 0 g  | 0 mol | 0 U |
#   +----------------+--------+------+-------+-----+]]
